# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

from graph_tool.all import *
import numpy as np
import matplotlib.pyplot as plt

from scripts.hrg import *
from scripts import visualization as viz

viz.load_matplotlib()
plt = viz.plt
plt.style.use('seaborn-poster')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import networkx as nx

dendrogram = load_dendrogram('../data/example_hrg1.txt')
plot_dendrogram(dendrogram)

# %%
dendrogram = load_dendrogram('../data/example_hrg1.txt')
g = generate_hrg(dendrogram)
viz.draw_network(g)

# %%
dendrogram = load_dendrogram('../data/example_hrg1.txt')
g = generate_hrg(dendrogram, to_gt=False)
print(np.mean(list(dict(g.degree()).values())))
# viz.draw_network(g)
# Out:
# 33.27076923076923

# %%
plt.hist(list(dict(g.degree()).values()))
# Out:
# (array([212., 299., 138.,  40.,  18.,  54., 200., 220., 102.,  17.]),
#  array([ 3. ,  9.5, 16. , 22.5, 29. , 35.5, 42. , 48.5, 55. , 61.5, 68. ]),
#  <BarContainer object of 10 artists>)

# %%
avg_degree(dendrogram)
# Out:
# 33.08461538461538
